# %%
import pandas as pd

# %%
f_train = open('./sentence-sentiment-analysis/train.tsv')

# %%
f_train = open('./sentence-sentiment-analysis/train.tsv')
data = []
label = []
for line in f_train.readlines():
    line = line.strip().split('\t')
    temp = []
    data.append(line[3])
    if line[2] == 'negative':
        label.append(0)
    elif line[2] == 'neutral':
        label.append(1)
    else:
        label.append(2)
f_train.close()

# %%
len(data)
# Out:
# 10026

# %%
len(label)
# Out:
# 10026

# %%
df = pd.DataFrame(data, columns=['text'])
df.to_csv('train.csv', index = False)

# %%
df.insert(0, 'label', label)

# %%
df.to_csv('train.csv', index = False)

# %%
import numpy as np
t = np.array(df)

# %%
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def review_to_wordlist( review, remove_stopwords=False ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(review).get_text()
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %%
review_to_wordlist(t[0][0])
# Out:
# ['gas',
#  'by',
#  'my',
#  'house',
#  'hit',
#  'i',
#  'm',
#  'going',
#  'to',
#  'chapel',
#  'hill',
#  'on',
#  'sat']

# %%
import nltk
# Load the punkt tokenizer
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# Define a function to split a review into parsed sentences
def review_to_sentences( review, tokenizer, remove_stopwords=False ):
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    raw_sentences = tokenizer.tokenize(review.strip())
    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
se = np.array(df['text'])
datas = []
for review in se:
    datas += review_to_sentences(review, tokenizer)
# Out:
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/7ZDEfzEC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/DlXY0LCg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/YI4r8UFM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/c9PmolGw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/FmoCg7YK" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/1RYso3ZZ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/WzO0bhVm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/f0LKm17i" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/7x8OfC56" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/sJGYXZsG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/UK8xRlos" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/3E1XyRnx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/qffIfZNN" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/8gnNmLPb" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/gwxw8wCH" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/WxVoBdek" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/zkZFOhfm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/UHtyOrLJ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/HhwLDdhF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/LegSwA9x" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/5106ZL2k" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/KcBgoqLv" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/30fmUpli" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/XUjEDHDe" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/BkQnxEC0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/byrH1xy8" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/qUaLO020" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/iIAxfJn3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/u84VkEEo" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/TDlEGKDw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/RjN9RrFT" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/n8ptYIrE" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/oMptA9pe" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/PjZePVti" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/b74QaR0B" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/bgIIj0Il" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/acSv9rKl" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/BzaPx4Di" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/lySbvgCo" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co
" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/Mw6EJbP7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/IwZVRW4e" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/eV0ApCF9" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/J4qqgga5"Yeaa!" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/idYGpj0D" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/saDzgClg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/nu18lhZP" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/7lS2nlwt" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/4uPUjBXD" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/C7499uAx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/nKabGiJO" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/4VUXdvqZ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/HTvr3XOS" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# D:\anaconda\lib\site-packages\bs4\__init__.py:336: UserWarning: "http://t.co/cgqRmbuf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
datas[0]
# Out:
# ['gas', 'by', 'my', 'house', 'hit']

# %%
# Import the built-in logging module and configure it so that Word2Vec 
# creates nice output messages
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print('Training model...')
model = word2vec.Word2Vec(datas, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# If you don't plan to train the model any further, calling 
# init_sims will make the model much more memory-efficient.
model.init_sims(replace=True)

# It can be helpful to create a meaningful model name and 
# save the model for later use. You can load it later using Word2Vec.load()
model_name = "300features_40minwords_10context"
model.save(model_name)
# Out:
# 2019-05-17 01:28:10,630 : INFO : collecting all words and their counts
# 2019-05-17 01:28:10,630 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-05-17 01:28:10,662 : INFO : PROGRESS: at sentence #10000, processed 109009 words, keeping 15322 word types
# 2019-05-17 01:28:10,696 : INFO : collected 23403 word types from a corpus of 200075 raw words and 18707 sentences
# 2019-05-17 01:28:10,697 : INFO : Loading a fresh vocabulary
# 2019-05-17 01:28:10,709 : INFO : effective_min_count=40 retains 519 unique words (2% of original 23403, drops 22884)
# 2019-05-17 01:28:10,710 : INFO : effective_min_count=40 leaves 131411 word corpus (65% of original 200075, drops 68664)
# 2019-05-17 01:28:10,713 : INFO : deleting the raw counts dictionary of 23403 items
# 2019-05-17 01:28:10,716 : INFO : sample=0.001 downsamples 72 most-common words
# 2019-05-17 01:28:10,718 : INFO : downsampling leaves estimated 81553 word corpus (62.1% of prior 131411)
# 2019-05-17 01:28:10,720 : INFO : estimated required memory for 519 words and 300 dimensions: 1505100 bytes
# 2019-05-17 01:28:10,722 : INFO : resetting layer weights
# 2019-05-17 01:28:10,741 : INFO : training model with 4 workers on 519 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# Training model...
# 2019-05-17 01:28:10,839 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-17 01:28:10,844 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-05-17 01:28:10,845 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-05-17 01:28:10,852 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-05-17 01:28:10,853 : INFO : EPOCH - 1 : training on 200075 raw words (81547 effective words) took 0.1s, 829133 effective words/s
# 2019-05-17 01:28:10,942 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-17 01:28:10,945 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-05-17 01:28:10,947 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-05-17 01:28:10,951 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-05-17 01:28:10,953 : INFO : EPOCH - 2 : training on 200075 raw words (81501 effective words) took 0.1s, 932712 effective words/s
# 2019-05-17 01:28:11,039 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-17 01:28:11,041 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-05-17 01:28:11,047 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-05-17 01:28:11,049 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-05-17 01:28:11,051 : INFO : EPOCH - 3 : training on 200075 raw words (81370 effective words) took 0.1s, 933340 effective words/s
# 2019-05-17 01:28:11,138 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-17 01:28:11,140 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-05-17 01:28:11,148 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-05-17 01:28:11,149 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-05-17 01:28:11,151 : INFO : EPOCH - 4 : training on 200075 raw words (81604 effective words) took 0.1s, 936473 effective words/s
# 2019-05-17 01:28:11,240 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-05-17 01:28:11,244 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-05-17 01:28:11,245 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-05-17 01:28:11,249 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-05-17 01:28:11,251 : INFO : EPOCH - 5 : training on 200075 raw words (81681 effective words) took 0.1s, 928454 effective words/s
# 2019-05-17 01:28:11,253 : INFO : training on a 1000375 raw words (407703 effective words) took 0.5s, 797844 effective words/s
# 2019-05-17 01:28:11,255 : INFO : precomputing L2-norms of word weight vectors
# 2019-05-17 01:28:11,262 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2019-05-17 01:28:11,263 : INFO : not storing attribute vectors_norm
# 2019-05-17 01:28:11,264 : INFO : not storing attribute cum_table
# 2019-05-17 01:28:11,265 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-17 01:28:11,284 : INFO : saved 300features_40minwords_10context

# %%
model.most_similar("man")
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2019-05-17 01:32:15,576 : INFO : precomputing L2-norms of word weight vectors
# D:\anaconda\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('gets', 0.9998095035552979),
#  ('amazing', 0.9995471239089966),
#  ('class', 0.9995341897010803),
#  ('finally', 0.9992864727973938),
#  ('hot', 0.9992623329162598),
#  ('taking', 0.9992525577545166),
#  ('life', 0.9992377758026123),
#  ('pass', 0.9991960525512695),
#  ('lost', 0.9989701509475708),
#  ('song', 0.9989230036735535)]

# %%
from gensim.models import Word2Vec
model = Word2Vec.load("300features_40minwords_10context")
# Out:
# 2019-05-17 01:28:16,979 : INFO : loading Word2Vec object from 300features_40minwords_10context
# 2019-05-17 01:28:16,980 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-17 01:28:16,992 : INFO : loading wv recursively from 300features_40minwords_10context.wv.* with mmap=None
# 2019-05-17 01:28:16,993 : INFO : setting ignored attribute vectors_norm to None
# 2019-05-17 01:28:16,994 : INFO : loading vocabulary recursively from 300features_40minwords_10context.vocabulary.* with mmap=None
# 2019-05-17 01:28:16,994 : INFO : loading trainables recursively from 300features_40minwords_10context.trainables.* with mmap=None
# 2019-05-17 01:28:16,995 : INFO : setting ignored attribute cum_table to None
# 2019-05-17 01:28:16,995 : INFO : loaded 300features_40minwords_10context

# %%
model['house']
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-5.17751575e-02, -2.67302785e-02, -7.38952830e-02,  2.35556308e-02,
#        -2.05581672e-02, -9.35992785e-03,  3.25652696e-02, -5.65519296e-02,
#        -1.43976463e-02,  1.15734018e-01,  4.47112322e-02, -1.52086139e-01,
#        -7.08456859e-02, -5.99065199e-02,  2.94682868e-02,  3.53649184e-02,
#         5.00433259e-02, -4.67994995e-02,  3.52042578e-02,  1.25089496e-01,
